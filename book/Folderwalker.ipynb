# %%
#replace single text
import os

def replace_text_in_md_files(directory, old_text, new_text):
    # Walk through the directory
    for root, dirs, files in os.walk(directory):
        for file in files:
            if file.endswith('.md'):
                file_path = os.path.join(root, file)
                with open(file_path, 'r', encoding='utf-8') as f:
                    content = f.read()
                
                # Replace the old text with the new text
                updated_content = content.replace(old_text, new_text)
                
                # Write the updated content back to the file
                with open(file_path, 'w', encoding='utf-8') as f:
                    f.write(updated_content)
                print(f"Updated: {file_path}")

# Specify the directory to start the search
directory_to_search = 'C:/Users/fpols/Documents/GitHub/Contemporary Physics/Demolab'

# Specify the old text to replace and the new text
# old_text_to_replace = '## Remarks \n **'
# new_replacement_text = '## Remarks \n *'



old_text_to_replace = '## Remarks\n** '
new_replacement_text = '## Remarks\n * '

# Run the function
replace_text_in_md_files(directory_to_search, old_text_to_replace, new_replacement_text)
# Out:
# Updated: C:/Users/fpols/Documents/GitHub/Contemporary Physics/Demolab\README.md
# Updated: C:/Users/fpols/Documents/GitHub/Contemporary Physics/Demolab\book\references.md
# Updated: C:/Users/fpols/Documents/GitHub/Contemporary Physics/Demolab\book\book\index.md
# Updated: C:/Users/fpols/Documents/GitHub/Contemporary Physics/Demolab\book\book\0 introduction\Contact.md
# Updated: C:/Users/fpols/Documents/GitHub/Contemporary Physics/Demolab\book\book\0 introduction\introduction.md
# Updated: C:/Users/fpols/Documents/GitHub/Contemporary Physics/Demolab\book\book\0 introduction\Workflow.md
# Updated: C:/Users/fpols/Documents/GitHub/Contemporary Physics/Demolab\book\book\1 mechanics\1 TOC.md
# Updated: C:/Users/fpols/Documents/GitHub/Contemporary Physics/Demolab\book\book\1 mechanics\1A measurement\1A TOC.md
# Updated: C:/Users/fpols/Documents/GitHub/Contemporary Physics/Demolab\book\book\1 mechanics\1A measurement\1A20 Error and Accuracy\1A20 TOC.md
# ...

# %%
# replace with file name edit
import os

def replace_text_in_md_files(directory, old_text, text_suffix):
    # Walk through the directory
    for root, dirs, files in os.walk(directory):
        for file in files:
            if file.endswith('.md'):
                file_path = os.path.join(root, file)
                
                # Extract the filename without extension
                filename_without_extension = os.path.splitext(file)[0]
                
                # Construct the new replacement text
                new_replacement_text = filename_without_extension + text_suffix
                
                with open(file_path, 'r', encoding='utf-8') as f:
                    content = f.read()
                
                # Replace the old text with the new text
                updated_content = content.replace(old_text, new_replacement_text)
                
                # Write the updated content back to the file
                with open(file_path, 'w', encoding='utf-8') as f:
                    f.write(updated_content)
                
                print(f"Updated: {file_path}")

# Specify the directory to start the search
directory_to_search = '/path/to/your/directory'

# Specify the old text to replace
old_text_to_replace = '[Diagram]()'

# Define the suffix text to append after the filename
text_suffix = ' text'  # Adjust this as needed

# Run the function
replace_text_in_md_files(directory_to_search, old_text_to_replace, text_suffix)

# %%
import os

def remove_dot_from_folder_names(directory):
    # Walk through the directory, including subdirectories
    for root, dirs, files in os.walk(directory, topdown=False):
        for dir_name in dirs:
            # Check if the directory name has a dot somewhere in the middle
            if '.' in dir_name and not dir_name.startswith('.') and not dir_name.endswith('.'):
                new_dir_name = dir_name.replace('.', '')
                old_path = os.path.join(root, dir_name)
                new_path = os.path.join(root, new_dir_name)
                
                try:
                    # Rename the directory
                    os.rename(old_path, new_path)
                    print(f"Renamed: {old_path} -> {new_path}")
                except OSError as e:
                    print(f"Error renaming {old_path} to {new_path}: {e}")

# Specify the directory to start the search
directory_to_search = 'c:/users/fpols/documents/github/contemporary physics/demolab/book/book'

# Run the function
remove_dot_from_folder_names(directory_to_search)

# %%
import os
import re

def find_incorrect_figure_blocks(directory):
    # List to store filenames with incorrect figure blocks
    incorrect_files = []

    # Walk through the directory and its subdirectories
    for root, dirs, files in os.walk(directory):
        for file in files:
            if file.endswith('.md'):
                file_path = os.path.join(root, file)
                
                # Read the file content
                with open(file_path, 'r', encoding='utf-8') as f:
                    content = f.read()

                # Find all occurrences of ```{figure} and check for closing ```
                figure_blocks = re.findall(r'```{figure}.*?```', content, re.DOTALL)
                all_figures = re.findall(r'```{figure}', content)

                # Check if the number of {figure} blocks matches the number of closing ```
                if len(figure_blocks) != len(all_figures):
                    incorrect_files.append(file_path)

    return incorrect_files

# Specify the directory to start the search
directory_to_search = 'c:/users/fpols/documents/github/contemporary physics/demolab/book'

# Run the function and print the result
incorrect_files = find_incorrect_figure_blocks(directory_to_search)

# Print the names of files with incorrect figure blocks
if incorrect_files:
    print("Files with incorrect figure blocks:")
    for file in incorrect_files:
        print(file)
else:
    print("All figure blocks are correctly closed.")
# Out:
# Files with incorrect figure blocks:
# c:/users/fpols/documents/github/contemporary physics/demolab/book\_build\html\_sources\book\1 mechanics\1D 2D motion\1D40 Center of Mass\1D4004 Explosion\1D4004.md
# c:/users/fpols/documents/github/contemporary physics/demolab/book\_build\html\_sources\book\1 mechanics\1Q rot dyn\1Q60 Rot Stability\1Q6003 Stable Wheel\1Q6003.md
# c:/users/fpols/documents/github/contemporary physics/demolab/book\_build\html\_sources\book\3 oscillations and waves\3B wave\3B10 Transverse\3B1001 Reflections of Transverse Pulses\3B1001.md
# c:/users/fpols/documents/github/contemporary physics/demolab/book\_build\html\_sources\book\3 oscillations and waves\3B wave\3B22 Standing\3B2203 Kundts Tube\3B2203.md
# c:/users/fpols/documents/github/contemporary physics/demolab/book\_build\html\_sources\book\4 thermodynamics\4D kinetic theory\4D30 Kinetic Motion\4D3002 Rain of Balls\4D3002.md
# ...

# %%
import os
from docx import Document

def replace_text_in_docx_files(directory, old_text, new_text):
    # Walk through the directory
    for root, dirs, files in os.walk(directory):
        for file in files:
            if file.endswith('.docx'):
                file_path = os.path.join(root, file)
                
                # Load the document
                doc = Document(file_path)
                
                # Iterate over all paragraphs in the document
                for paragraph in doc.paragraphs:
                    if old_text in paragraph.text:
                        paragraph.text = paragraph.text.replace(old_text, new_text)
                
                # Save the updated document
                doc.save(file_path)
                print(f"Updated: {file_path}")

# Specify the directory to start the search
directory_to_search = 'C:/Users/fpols/Documents/SEC'

# Specify the old text to replace and the new text
old_text_to_replace = 'vakcoach'
new_replacement_text = 'werkplekbegeleider'

# Run the function
replace_text_in_docx_files(directory_to_search, old_text_to_replace, new_replacement_text)
# Out:
# Updated: C:/Users/fpols/Documents/SEC\112023 Checklist Stage Basis.docx
# Updated: C:/Users/fpols/Documents/SEC\112023 Checklist Stage Verdiepend.docx
# Updated: C:/Users/fpols/Documents/SEC\2223 Q1 Lesplan- en lesevaluatieformulier.docx
# Updated: C:/Users/fpols/Documents/SEC\2223 Q1 Lessenserie plannen en evalueren.docx
# Updated: C:/Users/fpols/Documents/SEC\Aanpak PDCA 201112.docx
# Updated: C:/Users/fpols/Documents/SEC\Aanpak PDCA 240907.docx
# Updated: C:/Users/fpols/Documents/SEC\Algemeen-lesobservatieformulier-I.docx
# Updated: C:/Users/fpols/Documents/SEC\Algemeen-lesobservatieformulier-II.docx
# Updated: C:/Users/fpols/Documents/SEC\Algemeen-lesobservatieformulier-III.docx
# Updated: C:/Users/fpols/Documents/SEC\Beoordeling-Stage-Basis-versie-14-07-2021 (3).docx
# Updated: C:/Users/fpols/Documents/SEC\Beoordeling-Stage-Basis-versie-14-07-2021.docx
# Updated: C:/Users/fpols/Documents/SEC\Beoordeling-Stage-Verdieping-versie-18-08-2022 (1).docx
# ...

# %%
import os
from docx import Document

def find_files_with_text(directory, search_text):
    files_with_text = []

    # Walk through the directory
    for root, dirs, files in os.walk(directory):
        for file in files:
            if file.endswith('.docx'):
                file_path = os.path.join(root, file)
                
                # Load the document
                doc = Document(file_path)
                
                # Check if the search text is in any paragraph of the document
                for paragraph in doc.paragraphs:
                    if search_text in paragraph.text:
                        files_with_text.append(file_path)
                        print(f"Found '{search_text}' in: {file_path}")
                        break  # Stop checking further once the text is found

    return files_with_text

# Specify the directory to start the search
directory_to_search = 'C:/Users/fpols/Documents/Github/Contemporary Physics/Demolab/book'

# Specify the text to search for
search_text = '()'

# Run the function
found_files = find_files_with_text(directory_to_search, search_text)

# Print the results
print(f"\nTotal files containing '{search_text}': {len(found_files)}")
# Out:
# ---------------------------------------------------------------------------
# PackageNotFoundError                      Traceback (most recent call last)
# Cell In[9], line 32
#      29 search_text = '()'
#      31 # Run the function
# ---> 32 found_files = find_files_with_text(directory_to_search, search_text)
#      34 # Print the results
#      35 print(f"\nTotal files containing '{search_text}': {len(found_files)}")
#
# Cell In[9], line 14, in find_files_with_text(directory, search_text)
#      11 file_path = os.path.join(root, file)
#      13 # Load the document
# ---> 14 doc = Document(file_path)
#      16 # Check if the search text is in any paragraph of the document
#      17 for paragraph in doc.paragraphs:
#
# File c:\Users\fpols\Miniconda3\lib\site-packages\docx\api.py:25, in Document(docx)
#      18 """
#      19 Return a |Document| object loaded from *docx*, where *docx* can be
#      20 either a path to a ``.docx`` file (a string) or a file-like object. If
# ...

# %%
# looking for text in markdown files, return the files with the text
import os

def find_files_with_text(directory, search_text):
    files_with_text = []

    # Walk through the directory
    for root, dirs, files in os.walk(directory):
        for file in files:
            if file.endswith('.md'):
                file_path = os.path.join(root, file)
                
                # Open and read the markdown file
                with open(file_path, 'r', encoding='utf-8') as md_file:
                    content = md_file.read()
                    
                    # Check if the search text is in the file's content
                    if search_text in content:
                        files_with_text.append(file_path)
                        print(f"Found '{search_text}' in: {file_path}")

    return files_with_text

# Specify the directory to start the search
directory_to_search = 'C:/Users/fpols/Documents/Github/Contemporary Physics/Demolab/book'

# Specify the text to search for
search_text = '## Remarks\n** '

# Run the function
found_files = find_files_with_text(directory_to_search, search_text)

# Print the results
print(f"\nTotal files containing '{search_text}': {len(found_files)}")
# Out:
# Total files containing '## Remarks
# ** ': 0
