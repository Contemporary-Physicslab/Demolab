# %% [markdown]
# ````{mark}
# This marks some comments
# ````
#
# ## 1G Newton's Second Law plot

# %%
# -*- coding: utf-8 -*-
"""
Created on Thu Dec 08 13:29:31 2023
@author: rhaaksman
"""
# Out:
# '\nCreated on Thu Dec 08 13:29:31 2023\n@author: rhaaksman\n'
